# %% [markdown]
# ## Random forest regression

# %% [markdown]
#  - A Random Forest is an ensemble of Decision Trees, generally <br>
#  trained via the bagging method (or sometimes pasting), typically with max_samples <br>
#  set to the size of the training set.
#
# - Instead of building a BaggingClassifier and passing <br>
#  it a DecisionTreeClassifier, you can instead use the RandomForestClassifier <br>
#  class, which is more convenient and optimized for Decision Trees.
#
#
# - Similarly, there is a RandomForestRegressor class for regression tasks.
#
# #### Bagging
#
#  - The Approach is to use the same training algorithm for every <br>
#  predictor, but to train them on different random subsets of the training set.
#
#
#  - When sampling is performed with replacement, this method is called bagging (short for <br>
#  bootstrap aggregating). When sampling is performed without replacement, it is called <br>
#  pasting.
#
#
#  - Once all predictors are trained, the ensemble can make a prediction for a new <br>
#  instance by simply aggregating the predictions of all predictors. The aggregation <br>
#  function is typically the statistical mode.

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv('Real_Estate.csv', index_col='No')
dataset.head()
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#
#     Y house price of unit area
# No
# 1                         37.9
# 2                         42.2
# 3                         47.3
# 4                         54.8
# 5                         43.1

# %%
X = dataset.iloc[:, : -1].values
y = dataset.iloc[:, -1].values

# %%
corr = dataset.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col2 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col3 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col4 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col5 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col6 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow1_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow1_col2 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow1_col3 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow1_col4 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow1_col5 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow1_col6 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow2_col0 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow2_col1 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow3_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow3_col1 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow3_col2 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow3_col4 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow3_col5 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow3_col6 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow4_col0 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow4_col1 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow4_col2 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow4_col3 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow4_col5 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow4_col6 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow5_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow5_col3 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow5_col4 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow5_col6 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow6_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow6_col2 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow6_col3 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow6_col4 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow6_col5 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_0965bbe8_c52f_11ea_a785_d4258b8a2cfc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >X1 transaction date</th>        <th class="col_heading level0 col1" >X2 house age</th>        <th class="col_heading level0 col2" >X3 distance to the nearest MRT station</th>        <th class="col_heading level0 col3" >X4 number of convenience stores</th>        <th class="col_heading level0 col4" >X5 latitude</th>        <th class="col_heading level0 col5" >X6 longitude</th>        <th class="col_heading level0 col6" >Y house price of unit area</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0965bbe8_c52f_11ea_a785_d4258b8a2cfclevel0_row0" class="row_heading level0 row0" >X1 transaction date</th>
#                         <td id="T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col1" class="data row0 col1" >0.0175488</td>
#                         <td id="T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col2" class="data row0 col2" >0.06088</td>
#                         <td id="T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col3" class="data row0 col3" >0.00963544</td>
#                         <td id="T_0965bbe8_c52f_11ea_a785_d4258b8a2cfcrow0_col4" class="data row0 col4" >0.0350578</td>
#                         <td id="T_0965bbe8_c52f_11ea_a785_d4258b8a

# %% [markdown]
# ### Splitting the dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Training

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=500, max_leaf_nodes=16)
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=16,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_predicted = rf_regressor.predict(X_test)
score = rf_regressor.score(X_test, y_test)
score

# y_predicted = np.expand_dims(y_predicted, axis=1)
# y_test = np.expand_dims(y_test, axis=1)
# np.concatenate((y_predicted, y_test), axis=1);
# Out:
# 0.7336111864989442
